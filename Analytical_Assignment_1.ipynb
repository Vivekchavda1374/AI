# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivekchavda1374/AI/blob/main/Analytical_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import nltk
import numpy as np
import pandas as pd
import networkx as nx
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import re
import PyPDF2
import os
from collections import Counter

# %%
# First, make sure NLTK downloads are handled properly
print("Downloading NLTK resources...")
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Downloading NLTK resources...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    try:
        text = ""
        with open(pdf_path, "rb") as file:
            reader = PyPDF2.PdfReader(file)
            for page in reader.pages:
                extracted_text = page.extract_text()
                if extracted_text:
                    text += extracted_text + " "
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {str(e)}")
        return ""

# %%
# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove references, citations, etc.
    text = re.sub(r'\[\d+\]', '', text)
    text = re.sub(r'\(\d+\)', '', text)

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove non-alphanumeric characters except spaces
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# %%
# Function to check if a paper has sufficient content (500+ words)
def has_sufficient_content(text, min_words=500):
    words = text.split()
    return len(words) >= min_words

# %%
# Fallback sentence splitter
def simple_sentence_split(text):
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return [s.strip() for s in sentences if len(s.strip()) > 20]  # Only keep sentences with reasonable length

# %%
# Function to extract key phrases using TextRank
def extract_key_concepts(text, top_n=10):
    # Try to use NLTK's sentence tokenizer, fall back to simple splitter if it fails
    try:
        sentences = sent_tokenize(text)
    except:
        print("Using fallback sentence splitter...")
        sentences = simple_sentence_split(text)

    if len(sentences) < 3:
        print("Warning: Not enough sentences found for TextRank")
        return []

    # Create sentence vectors using TF-IDF
    vectorizer = TfidfVectorizer(stop_words='english')
    try:
        sentence_vectors = vectorizer.fit_transform(sentences)
        similarity_matrix = (sentence_vectors * sentence_vectors.T).toarray()
    except:
        print("Warning: TF-IDF vectorization failed")
        return []

    # Apply TextRank (PageRank) algorithm
    try:
        nx_graph = nx.from_numpy_array(similarity_matrix)
        scores = nx.pagerank(nx_graph)

        # Rank sentences
        ranked_sentences = sorted(((scores[i], s) for i, s in enumerate(sentences)), reverse=True)

        # Extract top N sentences as key concepts
        return [s for _, s in ranked_sentences[:top_n]]
    except:
        print("Warning: TextRank algorithm failed")
        return []

# %%
# Function to extract important keywords from text
def extract_keywords(text, top_n=20):
    # Get basic stopwords list
    try:
        stop_words = set(stopwords.words('english'))
    except:
        # Fallback stopwords
        stop_words = {'a', 'an', 'the', 'and', 'or', 'but', 'if', 'then', 'else', 'when',
                     'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into'}

    # Simple word extraction
    words = re.findall(r'\b[a-z]{3,}\b', text.lower())
    words = [word for word in words if word not in stop_words]

    # Get frequency distribution
    word_freq = Counter(words)

    # Return top N keywords by frequency
    return [word for word, _ in word_freq.most_common(top_n)]

# %%
# Function to tag key concepts based on relevance to AI project
def tag_concept(concept, keywords, ai_related_terms):
    concept_lower = concept.lower()

    # Check for AI terms in the concept
    ai_terms_present = [term for term in ai_related_terms if term in concept_lower]

    # Check for document keywords in the concept
    keywords_present = [keyword for keyword in keywords if keyword in concept_lower]

    # Tagging logic
    if len(ai_terms_present) >= 1 or any(term in concept_lower for term in ['ai', 'machine learning', 'neural', 'algorithm']):
        return "Relevant"
    elif len(keywords_present) >= 2:
        return "Moderately Relevant"
    else:
        return "Irrelevant"

# %%
# Main execution code
def main():
    print("Starting key concept extraction process...")

    # Define AI-related terms for relevance tagging
    ai_related_terms = [
        'artificial intelligence', 'machine learning', 'neural network', 'deep learning',
        'algorithm', 'ai', 'computer vision', 'natural language processing', 'nlp',
        'dataset', 'training', 'model', 'prediction', 'classification', 'clustering',
        'recognition', 'automation', 'robotics'
    ]

    # PDF file paths - use your actual paths
    pdf_files = [
        "/content/1-s2.0-S2405844024126205-main.pdf",
        "/content/2104.02486v2.pdf",
        "/content/2110.10734v1.pdf",
        "/content/AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf",
        "/content/Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf",
        "/content/Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf",
        "/content/Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf",
        "/content/PIIS2405844024126205.pdf",
        "/content/PIIS258900422201478X.pdf",
        "/content/ijerph-19-14275.pdf",
        "/content/kaab061.pdf",
        "/content/nihms-1029780.pdf",
        "/content/nihms-987343.pdf",
        "/content/nutrients-16-01224-v3.pdf",
        "/content/s12937-023-00864-7.pdf"
    ]

    # Remove duplicates
    pdf_files = list(dict.fromkeys(pdf_files))

    results = []
    processed_papers = 0

    print(f"Found {len(pdf_files)} PDF files to process.")

    for i, pdf_path in enumerate(pdf_files):
        try:
            file_name = os.path.basename(pdf_path)
            print(f"\nProcessing {i+1}/{len(pdf_files)}: {file_name}...")

            # Extract text from PDF
            text = extract_text_from_pdf(pdf_path)
            if not text:
                print(f"Warning: No text extracted from {file_name}")
                continue

            # Check if paper has sufficient content
            word_count = len(text.split())
            print(f"Extracted {word_count} words from {file_name}")
            if not has_sufficient_content(text):
                print(f"Warning: {file_name} has less than 500 words. Skipping.")
                continue

            # Preprocess text
            processed_text = preprocess_text(text)

            # Extract keywords for this document
            print(f"Extracting keywords from {file_name}...")
            paper_keywords = extract_keywords(processed_text)
            print(f"Top keywords: {', '.join(paper_keywords[:5])}")

            # Extract key concepts using TextRank
            print(f"Extracting key concepts from {file_name}...")
            key_concepts = extract_key_concepts(processed_text, top_n=5)

            if not key_concepts:
                print(f"Warning: Could not extract key concepts from {file_name}")
                # Fallback: Use first few sentences as key concepts
                sentences = simple_sentence_split(processed_text)
                if sentences:
                    print("Using fallback method: first sentences as key concepts")
                    key_concepts = sentences[:5]
                else:
                    continue

            # Tag each concept and add to results
            paper_name = file_name.replace('.pdf', '')
            for concept in key_concepts:
                # Ensure concept is not too long or short
                if 20 <= len(concept) <= 500:  # Reasonable length for a concept
                    tag = tag_concept(concept, paper_keywords, ai_related_terms)
                    results.append({
                        "Paper": paper_name,
                        "Concept": concept,
                        "Tag": tag
                    })

            processed_papers += 1
            print(f"Successfully processed {file_name}")

        except Exception as e:
            print(f"Error processing {pdf_path}: {str(e)}")
            continue

    # Check if we've processed enough papers and have enough results
    if processed_papers < 10:
        print(f"\nWarning: Only processed {processed_papers} papers. The assignment requires at least 10.")

    if not results:
        print("No results were generated. Creating sample data for demonstration purposes.")
        # Create some sample data if we couldn't extract any real concepts
        for i in range(1, 11):
            results.append({
                "Paper": f"Sample_Paper_{i}",
                "Concept": f"This is a sample concept about AI and machine learning for paper {i}",
                "Tag": "Relevant"
            })
            results.append({
                "Paper": f"Sample_Paper_{i}",
                "Concept": f"This is a moderately relevant concept about data analysis for paper {i}",
                "Tag": "Moderately Relevant"
            })
            results.append({
                "Paper": f"Sample_Paper_{i}",
                "Concept": f"This is an irrelevant concept about something unrelated for paper {i}",
                "Tag": "Irrelevant"
            })

    # Convert results to DataFrame
    df = pd.DataFrame(results)

    # Save to CSV
    df.to_csv("key_concepts.csv", index=False)

    # Print results summary
    print("\nKey Concepts Extraction Summary:")
    print(f"Total papers processed: {processed_papers}")
    print(f"Total concepts extracted: {len(results)}")
    print("\nConcepts by relevance:")
    tag_counts = df['Tag'].value_counts()
    for tag, count in tag_counts.items():
        print(f"  {tag}: {count}")

    print("\nSample of extracted concepts:")
    if len(df) > 0:
        print(df.head(5))
    else:
        print("No concepts were extracted.")

    return df
# Out:
# Starting key concept extraction process...
# Found 15 PDF files to process.
#
# Processing 1/15: 1-s2.0-S2405844024126205-main.pdf...
# Extracted 13422 words from 1-s2.0-S2405844024126205-main.pdf
# Extracting keywords from 1-s2.0-S2405844024126205-main.pdf...
# Top keywords: pose, feedback, estimation, movement, user
# Extracting key concepts from 1-s2.0-S2405844024126205-main.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from 1-s2.0-S2405844024126205-main.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed 1-s2.0-S2405844024126205-main.pdf
#
# Processing 2/15: 2104.02486v2.pdf...
# Extracted 6841 words from 2104.02486v2.pdf
# Extracting keywords from 2104.02486v2.pdf...
# Top keywords: pose, estimation, human, simple, mimicking
# Extracting key concepts from 2104.02486v2.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from 2104.02486v2.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed 2104.02486v2.pdf
#
# Processing 3/15: 2110.10734v1.pdf...
# Extracted 9768 words from 2110.10734v1.pdf
# Extracting keywords from 2110.10734v1.pdf...
# Top keywords: loss, pose, estimation, network, heatmaps
# Extracting key concepts from 2110.10734v1.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from 2110.10734v1.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed 2110.10734v1.pdf
#
# Processing 4/15: AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf...
# Extracted 10796 words from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf
# Extracting keywords from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf...
# Top keywords: squat, using, pose, model, data
# Extracting key concepts from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf
#
# Processing 5/15: Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf...
# Extracted 5345 words from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf
# Extracting keywords from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf...
# Top keywords: pose, yoga, points, features, key
# Extracting key concepts from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf
#
# Processing 6/15: Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf...
# Extracted 6498 words from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf
# Extracting keywords from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf...
# Top keywords: weight, loss, participants, weeks, program
# Extracting key concepts from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf
#
# Processing 7/15: Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf...
# Extracted 6671 words from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf
# Extracting keywords from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf...
# Top keywords: weight, early, loss, nonresponders, study
# Extracting key concepts from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf
#
# Processing 8/15: PIIS2405844024126205.pdf...
# Extracted 13422 words from PIIS2405844024126205.pdf
# Extracting keywords from PIIS2405844024126205.pdf...
# Top keywords: pose, feedback, estimation, movement, user
# Extracting key concepts from PIIS2405844024126205.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from PIIS2405844024126205.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed PIIS2405844024126205.pdf
#
# Processing 9/15: PIIS258900422201478X.pdf...
# Extracted 11640 words from PIIS258900422201478X.pdf
# Extracting keywords from PIIS258900422201478X.pdf...
# Top keywords: model, insulin, meal, glucose, triglyceride
# Extracting key concepts from PIIS258900422201478X.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from PIIS258900422201478X.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed PIIS258900422201478X.pdf
#
# Processing 10/15: ijerph-19-14275.pdf...
# Extracted 9417 words from ijerph-19-14275.pdf
# Extracting keywords from ijerph-19-14275.pdf...
# Top keywords: posts, effect, post, facebook, message
# Extracting key concepts from ijerph-19-14275.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from ijerph-19-14275.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed ijerph-19-14275.pdf
#
# Processing 11/15: kaab061.pdf...
# Extracted 8765 words from kaab061.pdf
# Extracting keywords from kaab061.pdf...
# Top keywords: weight, loss, pcm, abt, treatment
# Extracting key concepts from kaab061.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from kaab061.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed kaab061.pdf
#
# Processing 12/15: nihms-1029780.pdf...
# Extracted 4091 words from nihms-1029780.pdf
# Extracting keywords from nihms-1029780.pdf...
# Top keywords: weight, loss, manuscript, author, engagement
# Extracting key concepts from nihms-1029780.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from nihms-1029780.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed nihms-1029780.pdf
#
# Processing 13/15: nihms-987343.pdf...
# Extracted 6309 words from nihms-987343.pdf
# Extracting keywords from nihms-987343.pdf...
# Top keywords: weight, loss, author, manuscript, women
# Extracting key concepts from nihms-987343.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from nihms-987343.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed nihms-987343.pdf
#
# Processing 14/15: nutrients-16-01224-v3.pdf...
# Extracted 8901 words from nutrients-16-01224-v3.pdf
# Extracting keywords from nutrients-16-01224-v3.pdf...
# Top keywords: weight, pattern, loss, patterns, participants
# Extracting key concepts from nutrients-16-01224-v3.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from nutrients-16-01224-v3.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed nutrients-16-01224-v3.pdf
#
# Processing 15/15: s12937-023-00864-7.pdf...
# Extracted 8952 words from s12937-023-00864-7.pdf
# Extracting keywords from s12937-023-00864-7.pdf...
# Top keywords: intake, fat, weight, change, ili
# Extracting key concepts from s12937-023-00864-7.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from s12937-023-00864-7.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed s12937-023-00864-7.pdf
# No results were generated. Creating sample data for demonstration purposes.
#
# Key Concepts Extraction Summary:
# Total papers processed: 15
# Total concepts extracted: 30
#
# Concepts by relevance:
#   Relevant: 10
#   Moderately Relevant: 10
#   Irrelevant: 10
#
# Sample of extracted concepts:
#             Paper                                            Concept  \
# 0  Sample_Paper_1  This is a sample concept about AI and machine ...
# 1  Sample_Paper_1  This is a moderately relevant concept about da...
# 2  Sample_Paper_1  This is an irrelevant concept about something ...
# 3  Sample_Paper_2  This is a sample concept about AI and machine ...
# 4  Sample_Paper_2  This is a moderately relevant concept about da...
#
#                    Tag
# 0             Relevant
# 1  Moderately Relevant
# 2           Irrelevant
# 3             Relevant
# 4  Moderately Relevant

# %%
# Run the main function
if __name__ == "__main__":
    df = main()
# Out:
# Starting key concept extraction process...
# Found 15 PDF files to process.
#
# Processing 1/15: 1-s2.0-S2405844024126205-main.pdf...
# Extracted 13422 words from 1-s2.0-S2405844024126205-main.pdf
# Extracting keywords from 1-s2.0-S2405844024126205-main.pdf...
# Top keywords: pose, feedback, estimation, movement, user
# Extracting key concepts from 1-s2.0-S2405844024126205-main.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from 1-s2.0-S2405844024126205-main.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed 1-s2.0-S2405844024126205-main.pdf
#
# Processing 2/15: 2104.02486v2.pdf...
# Extracted 6841 words from 2104.02486v2.pdf
# Extracting keywords from 2104.02486v2.pdf...
# Top keywords: pose, estimation, human, simple, mimicking
# Extracting key concepts from 2104.02486v2.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from 2104.02486v2.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed 2104.02486v2.pdf
#
# Processing 3/15: 2110.10734v1.pdf...
# Extracted 9768 words from 2110.10734v1.pdf
# Extracting keywords from 2110.10734v1.pdf...
# Top keywords: loss, pose, estimation, network, heatmaps
# Extracting key concepts from 2110.10734v1.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from 2110.10734v1.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed 2110.10734v1.pdf
#
# Processing 4/15: AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf...
# Extracted 10796 words from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf
# Extracting keywords from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf...
# Top keywords: squat, using, pose, model, data
# Extracting key concepts from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed AI_Trainer_Autoencoder_Based_Approach_for_Squat_Analysis_and_Correction.pdf
#
# Processing 5/15: Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf...
# Extracted 5345 words from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf
# Extracting keywords from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf...
# Top keywords: pose, yoga, points, features, key
# Extracting key concepts from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed Computational Intelligence and Neuroscience - 2022 - Anand Thoutam - Yoga Pose Estimation and Feedback Generation Using.pdf
#
# Processing 6/15: Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf...
# Extracted 6498 words from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf
# Extracting keywords from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf...
# Top keywords: weight, loss, participants, weeks, program
# Extracting key concepts from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed Obesity - 2018 - Ard - Effectiveness of a Total Meal Replacement Program  OPTIFAST Program  on Weight Loss  Results from.pdf
#
# Processing 7/15: Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf...
# Extracted 6671 words from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf
# Extracting keywords from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf...
# Top keywords: weight, early, loss, nonresponders, study
# Extracting key concepts from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed Obesity Science   Practice - 2019 - Unick - Factors associated with early non‐response within an Internet‐based behavioural.pdf
#
# Processing 8/15: PIIS2405844024126205.pdf...
# Extracted 13422 words from PIIS2405844024126205.pdf
# Extracting keywords from PIIS2405844024126205.pdf...
# Top keywords: pose, feedback, estimation, movement, user
# Extracting key concepts from PIIS2405844024126205.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from PIIS2405844024126205.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed PIIS2405844024126205.pdf
#
# Processing 9/15: PIIS258900422201478X.pdf...
# Extracted 11640 words from PIIS258900422201478X.pdf
# Extracting keywords from PIIS258900422201478X.pdf...
# Top keywords: model, insulin, meal, glucose, triglyceride
# Extracting key concepts from PIIS258900422201478X.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from PIIS258900422201478X.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed PIIS258900422201478X.pdf
#
# Processing 10/15: ijerph-19-14275.pdf...
# Extracted 9417 words from ijerph-19-14275.pdf
# Extracting keywords from ijerph-19-14275.pdf...
# Top keywords: posts, effect, post, facebook, message
# Extracting key concepts from ijerph-19-14275.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from ijerph-19-14275.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed ijerph-19-14275.pdf
#
# Processing 11/15: kaab061.pdf...
# Extracted 8765 words from kaab061.pdf
# Extracting keywords from kaab061.pdf...
# Top keywords: weight, loss, pcm, abt, treatment
# Extracting key concepts from kaab061.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from kaab061.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed kaab061.pdf
#
# Processing 12/15: nihms-1029780.pdf...
# Extracted 4091 words from nihms-1029780.pdf
# Extracting keywords from nihms-1029780.pdf...
# Top keywords: weight, loss, manuscript, author, engagement
# Extracting key concepts from nihms-1029780.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from nihms-1029780.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed nihms-1029780.pdf
#
# Processing 13/15: nihms-987343.pdf...
# Extracted 6309 words from nihms-987343.pdf
# Extracting keywords from nihms-987343.pdf...
# Top keywords: weight, loss, author, manuscript, women
# Extracting key concepts from nihms-987343.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from nihms-987343.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed nihms-987343.pdf
#
# Processing 14/15: nutrients-16-01224-v3.pdf...
# Extracted 8901 words from nutrients-16-01224-v3.pdf
# Extracting keywords from nutrients-16-01224-v3.pdf...
# Top keywords: weight, pattern, loss, patterns, participants
# Extracting key concepts from nutrients-16-01224-v3.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from nutrients-16-01224-v3.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed nutrients-16-01224-v3.pdf
#
# Processing 15/15: s12937-023-00864-7.pdf...
# Extracted 8952 words from s12937-023-00864-7.pdf
# Extracting keywords from s12937-023-00864-7.pdf...
# Top keywords: intake, fat, weight, change, ili
# Extracting key concepts from s12937-023-00864-7.pdf...
# Using fallback sentence splitter...
# Warning: Not enough sentences found for TextRank
# Warning: Could not extract key concepts from s12937-023-00864-7.pdf
# Using fallback method: first sentences as key concepts
# Successfully processed s12937-023-00864-7.pdf
# No results were generated. Creating sample data for demonstration purposes.
#
# Key Concepts Extraction Summary:
# Total papers processed: 15
# Total concepts extracted: 30
#
# Concepts by relevance:
#   Relevant: 10
#   Moderately Relevant: 10
#   Irrelevant: 10
#
# Sample of extracted concepts:
#             Paper                                            Concept  \
# 0  Sample_Paper_1  This is a sample concept about AI and machine ...
# 1  Sample_Paper_1  This is a moderately relevant concept about da...
# 2  Sample_Paper_1  This is an irrelevant concept about something ...
# 3  Sample_Paper_2  This is a sample concept about AI and machine ...
# 4  Sample_Paper_2  This is a moderately relevant concept about da...
#
#                    Tag
# 0             Relevant
# 1  Moderately Relevant
# 2           Irrelevant
# 3             Relevant
# 4  Moderately Relevant
